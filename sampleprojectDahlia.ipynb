# %% [markdown]
# <a href="https://colab.research.google.com/github/MDeluteAgrazamendez/Quarter2-Codes/blob/main/sampleprojectDahlia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
url = "https://raw.githubusercontent.com/MDeluteAgrazamendez/demoDahlia/refs/heads/main/students.json"
response = requests.get(url)
students = response.json()
print(students)
#make sure the url is the raw file from the github
# Out:
# {'students': [{'id': 1001, 'name': 'Czarina', 'grades': {'Math': 92, 'CS': 88}}, {'id': 1002, 'name': 'Miguel', 'grades': {'Math': 85, 'CS': 90}}]}

# %%
# !pip install firebase-admin

# %%
import requests
import json
import firebase_admin
from firebase_admin import credentials, db
# Step 1: Download the key from GitHub
url = "https://raw.githubusercontent.com/MDeluteAgrazamendez/demoDahlia/refs/heads/main/firebase_key_1.json"
response = requests.get(url)
# Step 2: Save it locally in Colab
with open("firebase_key.json", "wb") as f:
  f.write(response.content)
# Step 3: Initialize Firebase
# Check if the default Firebase app is already initialized
if not firebase_admin._apps:
  cred = credentials.Certificate("firebase_key.json")
  firebase_admin.initialize_app(cred, {'databaseURL': 'https://grade8-json-db-default-rtdb.asia-southeast1.firebasedatabase.app/'})
  print("Connected to Firebase!")
else:
  print("Firebase app already initialized.")
#make sure the url is the raw file from the github
# Out:
# Firebase app already initialized.

# %%
import requests
import json
# The 'students' variable is already loaded from the URL in a previous cell.
# Therefore, we can directly use the 'students' variable.
data = students
print("JSON file loaded")
ref = db.reference("students")
for student in data["students"]:
  ref.child(str(student["id"])).set(student)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# /tmp/ipython-input-681543657.py in <cell line: 0>()
#       7 ref = db.reference("students")
#       8 for student in data["students"]:
# ----> 9   ref.child(str(student["id"])).set(student)
#      10 print("Data uploaded successfully!")
#
# /usr/local/lib/python3.12/dist-packages/firebase_admin/db.py in set(self, value)
#     262         if value is None:
#     263             raise ValueError('Value must not be None.')
# --> 264         self._client.request('put', self._add_suffix(), json=value, params='print=silent')
#     265
#     266     def set_if_unchanged(self, expected_etag, value):
#
# /usr/local/lib/python3.12/dist-packages/firebase_admin/db.py in request(self, method, url, **kwargs)
#     927
#     928         try:
# --> 929             return super(_Client, self).request(method, url, **kwargs)
# ...
